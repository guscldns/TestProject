# %% [markdown]
# <a href="https://colab.research.google.com/github/guscldns/TestProject/blob/main/%EC%BD%94%EB%94%A9%ED%85%8C%EC%8A%A4%ED%8A%B8/%EC%BD%94%EB%94%A9%ED%85%8C%EC%8A%A4%ED%8A%B8_%EC%B5%9C%EC%A2%85%ED%9A%8C%EC%B0%A8_%ED%98%84%EC%B9%98%EC%9A%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. 할인행사

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import time

start = time.time()


def solution(want, number, discount):
# 답안 작성 부분 ===============
    a = {d: discount.count(d) for d in discount}
    b = {w:n for w,n in zip(want, number)}
    count = 0

    for i in a:
        if i in b :
            count += b[i]-a[i]

# ==============================

    return count * -1


end = time.time()

print(solution(["banana", "apple", "rice", "pork", "pot"],	[3, 2, 2, 2, 1], ["chicken", "apple", "apple", "banana", "rice", "apple", "pork", "banana", "pork", "rice", "pot", "banana", "apple", "banana"]))
print(solution(["apple"],	[10], ["banana", "banana", "banana", "banana", "banana", "banana", "banana", "banana", "banana", "banana"]))


print("작동시간:", f"{end - start:.5f} sec")
# Out:
# 3
# 0
# 작동시간: 0.00032 sec

# %% [markdown]
# ## 2. 의상

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import time

start = time.time()

def solution(clothes):
# 답안 작성 부분 ===============
    f = {}
    count = 1
    for i in clothes:
        if i[-1] in f:
            f[i[-1]] += 1
        else:
            f[i[-1]] = 1


    d = [v for i,v in f.items()]
    if len(f) == 1:
        return sum(d)
    for j in d:
        count *= j
    count += sum(d)
# ==============================

    return count

print(solution([["yellow_hat", "headgear"], ["blue_sunglasses", "eyewear"], ["green_turban", "headgear"]]))
print(solution([["crow_mask", "face"], ["blue_sunglasses", "face"], ["smoky_makeup", "face"]]))

end = time.time()

print("작동시간:", f"{end - start:.5f} sec")
# Out:
# 5
# 3
# 작동시간: 0.00280 sec

# %% [markdown]
# ## 3. 땅따먹기

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import time

start = time.time()


def solution(land):
# 답안 작성 부분 ===============
    a= []
    b = 0
    for i in land:
        j = i.index(max(i))

        if j not in a:
            a.append(j)
            b += max(i)
        else:
            i.remove(max(i))
            a.append(i.index(max(i)))
            b += max(i)
    return b
# ==============================



print(solution([[1,2,3,5],[5,6,7,8],[4,3,2,1]]))

end = time.time()

print("작동시간:", f"{end - start:.5f} sec")
# Out:
# 16
# 작동시간: 0.00217 sec

# %% [markdown]
# ## 4. k진수에서 소수 개수 구하기 (2022 KAKAO BLIND RECRUITMENT)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import time

start = time.time()

def solution(n, k):
# 답안 작성 부분 ===============
    rev_base = ''
    count = 0
    while n > 0:
        n, mod = divmod(n, k)
        rev_base += str(mod)

    num =rev_base[::-1]
    a = str(num).split('0')
    for i in a:
        # print(i)
        if i == '1' or len(i)==0:
            pass
        else:
            count += 1

# ==============================
    return count

print(solution(437674, 3))
print(solution(110011, 10))

end = time.time()

print("작동시간:", f"{end - start:.5f} sec")
# Out:
# 3
# 2
# 작동시간: 0.01104 sec

# %% [markdown]
# ## 5. 두 큐 합 같게 만들기 (2022 KAKAO TECH INTERNSHIP)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import time

start = time.time()


def solution(queue1, queue2):
# 답안 작성 부분 ===============
    t = (sum(queue1)+sum(queue2))//2
    count = 0
    while sum(queue1) != t:
        if max(queue1) > t or max(queue2) > t:
            return -1
        if sum(queue1) > t :
            a = queue1.pop(0)
            queue2.append(a)
            count += 1
        else:
            b = queue2.pop(0)
            queue1.append(b)
            count += 1
# ==============================

    return count

print(solution([3, 2, 7, 2],	[4, 6, 5, 1]))
print(solution([1, 2, 1, 2],	[1, 10, 1, 2]	))
print(solution([1, 1],	[1, 5]))

end = time.time()

print("작동시간:", f"{end - start:.5f} sec")
# Out:
# 2
# 7
# -1
# 작동시간: 0.00790 sec

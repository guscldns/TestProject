# %% [markdown]
# <a href="https://colab.research.google.com/github/guscldns/TestProject/blob/main/0508/01_crawling_basic(practice)_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. 삼성전자 뉴스 기사제목 100개 가져오기

# %%
https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=44&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start=1

# %% [markdown]
# #### 1-1. 이중 반복문을 이용하여 기사제목 100개 출력하기
#
# 1. url 10개 반복 requests get
# 2. soup(html)에서 select한 a태그 10개 반복 title 파싱하여 출력

# %%
import requests
from bs4 import BeautifulSoup

# %%
for i in range(1,100,10):
    url = requests.get('https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=44&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start={}'.format(i))
    soup = BeautifulSoup(url.content, 'lxml')    
    a_tags = soup.select('a.news_tit')
    for a_tag in a_tags:
        print(a_tag['title'])
# Out:
# 삼성전기 4.1% 임금인상 유력, "올해도 삼성전자가 기준"
# 삼성전자 파운드리, 출범 5년만에 매출 200억 달러 돌파
# [PS 산업] 삼성전자, LG전자, SKT
# "일하다 운 적 있다"…아무나 못하는 '0.02%' 삼성전자 사장
# 삼성전자가 '달수 인형'을 만든 이유
# “갤럭시 3대 팔아야 아이폰 1대 이익”… 삼성전자, 스마트폰 평균판매가 올려 수익성 방어 총력전
# 평택 삼성전자 협력업체 직원 '상습 휴대폰 절도' 혐의 입건
# 삼성전자 경계현 사장 "야근하다 눈물 왈칵"…무슨 일?
# 이재용 삼성전자 회장 "반도체 성공 DNA, 바이오 신화로 이어가자"
# ‘맏형’ 따라가는 삼성 전자계열사…삼성D, 4.1% 인상 합의
# '20조 손실' 버티면 웃는다…삼성전자·SK하이닉스 '고진감래' [김익환의 컴퍼니워치]
# 삼성전자, 반도체 이어 '바이오 신화' 이룬다
# 삼성전자, 3나노 2세대 '베일' 벗는다…"4나노와 비교 불가"
# 반도체 부진 車가 채운 1분기…삼성전자 비중 43.7% 급감
# “갤럭시 3대 팔아야 아이폰 1대 이익”… 삼성전자, 스마트폰 평균판매가 올려 수익성 방어 총력전
# "삼성전자 2분기 영업이익 전망 2,700억 원대...98%↓"
# "반도체株 지금이 바닥"…개인은 ETF, 외국인은 삼성전자 매집
# 평택 삼성전자 협력업체 직원 '상습 휴대폰 절도' 혐의 입건
# 삼성전자 감산효과는…"2분기말 시작, 하반기 극대화"
# 삼성전자, 유럽 최대 항구축제서 부산엑스포 홍보
# [뉴스줌인]삼성전자, 바이오 한미동맹 확인...“바이오 제2반도체로”
# 일현전자, 삼성스토어 용인처인·용인시청점 오픈
# 취준생 목표 1위 삼성전자 나와서 창업한 이 사람 [fn이사람]
# 삼성전자, 독일 함부르크 개항축제서 부산엑스포 홍보
# [주간 추천주] 실적 주목…삼성전자·한국전력·넷마블 '러브콜'
# '수소버스' 대중화 가속 … 삼성전자·포스코 등 2026년까지 통근버스 2000대로 확대
# ...

# %% [markdown]
# #### 1-2. 기사제목 저장할 리스트 선언하여 append하여 저장하기

# %%
import requests
from bs4 import BeautifulSoup

# %%
titles = []
for i in range(1,100,10):
    url = requests.get('https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=44&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start={}'.format(i))
    soup = BeautifulSoup(url.content, 'lxml')    
    a_tags = soup.select('a.news_tit')
    for a_tag in a_tags:
        titles.append(a_tag['title'])

# %%
len(titles)
# Out:
# 100

# %% [markdown]
# #### 1-3. 긴 url 쿼리스트링 따로 분리하기

# %%
titles = []

# %%
for i in range(10):
    start = i*10 + 1

    url = 'https://search.naver.com/search.naver?'

    params = {
    'where':'news',
    'query':'삼성전자',
    'start': start
    }

    resp = requests.get(url, params=params)



titles
# Out:
# ['검찰, 삼성전자 자회사 핵심기술 국외유출범 5명 기소',
#  '삼성전자, 강신봉 前 요기요 대표 영입…온라인 강화 목표',
#  '삼성전자, ‘e식품관’에서 새해맞이 프로모션 진행',
#  '삼성전자, 전세계 주요 도시에 갤럭시 체험공간 마련',
#  "삼성전자, 미국·영국·프랑스 등 24개 도시 '갤럭시 체험공간' 오픈",
#  '"땡큐 삼성전자"…미국 텍사스주에 생긴 \'삼성 고속도로\'',
#  '[종합] 尹대통령, UAE 바라카 원전 방문...이재용 삼성전자 회장 등 참석',
#  '만수르 부총리와 대화하는 이재용 삼성전자 회장',
#  '삼성전자 선행 PER 14년 만에 20배 돌파…"이익 바닥 신호"',
#  "이재용 회장이 '취토' 권한 이유...0.02% 삼성전자 사장의 조건 [삼성연구]",
#  "'어닝 쇼크' 삼성전자, 6만전자 탈환",
#  '경계현 삼성전자 사장 "美테일러에 삼성 고속도로…공장 연내 완공"',
#  '[종합] 尹대통령, UAE 바라카 원전 방문...이재용 삼성전자 회장 등 참석',
#  '"삼성전자보다 더 샀다"…올 들어 외국인·기관 4대 은행주 7000억원 순매수 [투자360]',
#  '한-UAE 비즈니스 포럼 참석한 이재용 삼성전자 회장',
#  '만수르 부총리와 대화하는 이재용 삼성전자 회장',
#  '윤석열 대통령과의 만찬 간담회 참석한 이재용 삼성전자 회장',
#  "삼성전자, 글로벌 ICT 기업 중 '공급망 인권침해 대처' 5위",
#  '삼성전자, 메모리 불황 장기화에 ‘기술적 감산’ 카드 꺼낼까',
#  '코스피, 2390선 상승 출발…삼성전자·LG엔솔 강세',
#  '한국투자증권, 월배당 ETF·삼성전자 주식 지급 이벤트 진행',
#  "삼성전자 美 테일러 반도체 공장 연내 완공… '삼성 고속도로'도 생겼다",
#  '[인터뷰]“고액자산가들 저쿠폰채·삼성전자 쇼핑”',
#  '그라비티, 삼성전자와 ‘라그나로크X’ 팝업 스토어 오픈',
# ...

# %%
 soup = BeautifulSoup(url.content, 'lxml')

# %% [markdown]
# ### 2. 알라딘

# %%
import requests
from bs4 import BeautifulSoup

# https://comic.naver.com/webtoon?tab=mon

# %% [markdown]
# #### 2-1. 제목, 작가, 평점 가져와서 딕셔너리에 저장하기

# %%
df_toons = {}
titles = []
authors = []
ratings = []

# %%
url = 'https://comic.naver.com/webtoon/weekdayList?week=mon'

resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.content, 'lxml')
webtoon = soup.select('a.ContentList__info_area--bXx7h')
for webt in webtoon:
    titles.append(webtoon['제목'])

# %% [markdown]
# #### 2-2. 전체 웹툰 제목, 작가, 평점 딕셔너리에 저장 -> csv파일로 저장

# %%
titles, authors, ratings = [], [], []

# %%
weekdays = ['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun']
# Out:
# https://comic.naver.com/webtoon/weekdayList?week=mon
# https://comic.naver.com/webtoon/weekdayList?week=tue
# https://comic.naver.com/webtoon/weekdayList?week=wed
# https://comic.naver.com/webtoon/weekdayList?week=thu
# https://comic.naver.com/webtoon/weekdayList?week=fri
# https://comic.naver.com/webtoon/weekdayList?week=sat
# https://comic.naver.com/webtoon/weekdayList?week=sun
# (578, 578, 578)

# %%
import pandas as pd

df_toons = pd.DataFrame({'제목': titles, '작가': authors, '평점' : ratings})
df_toons.to_csv('네이버웹툰정보.csv')

# %% [markdown]
# #### 2-3. url을 직접 수집해서 전체 웹툰 제목, 작가, 평점 딕셔너리에 저장 -> csv파일로 저장

# %%
# url 수집
# Out:
# ['https://comic.naver.com/webtoon/weekdayList?week=mon',
#  'https://comic.naver.com/webtoon/weekdayList?week=tue',
#  'https://comic.naver.com/webtoon/weekdayList?week=wed',
#  'https://comic.naver.com/webtoon/weekdayList?week=thu',
#  'https://comic.naver.com/webtoon/weekdayList?week=fri',
#  'https://comic.naver.com/webtoon/weekdayList?week=sat',
#  'https://comic.naver.com/webtoon/weekdayList?week=sun']

# %%
titles, authors, ratings = [], [], []

# %%
import pandas as pd

df_toons = pd.DataFrame({'title' : titles, 'author' : authors, 'rating' : ratings})
df_toons.to_csv('네이버웹툰정보.csv', index=False)

# %%
df_toons
# Out:
#           title             author rating
# 0           참교육          채용택 / 한가람   9.87
# 1       뷰티풀 군바리           설이 / 윤성원   9.81
# 2       퀘스트지상주의           박태준 만화회사   9.80
# 3     장씨세가 호위무사          김인호 / 조형근   9.93
# 4        윈드브레이커                조용석   9.83
# ..          ...                ...    ...
# 573     조선여우스캔들     문종호 / 정후 / 차소희   9.93
# 574   밀실 마피아 게임  WONS / 백지운 / P...   9.41
# 575  천년간 노려왔습니다                 수빈   9.90
# 576      그림자 잡기                 최날   9.64
# 577        어떤소란                 케첩   9.83
#
# [578 rows x 3 columns]

# %%
toon_info = pd.read_csv('네이버웹툰정보.csv', index_col='title')
toon_info
# Out:
#                        author  rating
# title
# 참교육                 채용택 / 한가람    9.87
# 뷰티풀 군바리              설이 / 윤성원    9.81
# 퀘스트지상주의              박태준 만화회사    9.80
# 장씨세가 호위무사           김인호 / 조형근    9.93
# 윈드브레이커                    조용석    9.83
# ...                       ...     ...
# 조선여우스캔들        문종호 / 정후 / 차소희    9.93
# 밀실 마피아 게임   WONS / 백지운 / P...    9.41
# 천년간 노려왔습니다                 수빈    9.90
# 그림자 잡기                     최날    9.64
# 어떤소란                       케첩    9.83
#
# [578 rows x 2 columns]

# %%
toon_info.reset_index(inplace=True)
toon_info
# Out:
#           title             author  rating
# 0           참교육          채용택 / 한가람    9.87
# 1       뷰티풀 군바리           설이 / 윤성원    9.81
# 2       퀘스트지상주의           박태준 만화회사    9.80
# 3     장씨세가 호위무사          김인호 / 조형근    9.93
# 4        윈드브레이커                조용석    9.83
# ..          ...                ...     ...
# 573     조선여우스캔들     문종호 / 정후 / 차소희    9.93
# 574   밀실 마피아 게임  WONS / 백지운 / P...    9.41
# 575  천년간 노려왔습니다                 수빈    9.90
# 576      그림자 잡기                 최날    9.64
# 577        어떤소란                 케첩    9.83
#
# [578 rows x 3 columns]

# %%
toon_info.set_index('title', inplace=True)
toon_info
# Out:
#                        author  rating
# title
# 참교육                 채용택 / 한가람    9.87
# 뷰티풀 군바리              설이 / 윤성원    9.81
# 퀘스트지상주의              박태준 만화회사    9.80
# 장씨세가 호위무사           김인호 / 조형근    9.93
# 윈드브레이커                    조용석    9.83
# ...                       ...     ...
# 조선여우스캔들        문종호 / 정후 / 차소희    9.93
# 밀실 마피아 게임   WONS / 백지운 / P...    9.41
# 천년간 노려왔습니다                 수빈    9.90
# 그림자 잡기                     최날    9.64
# 어떤소란                       케첩    9.83
#
# [578 rows x 2 columns]

# %% [markdown]
# #### 2-4. 전체웹툰 제목, 작가, 평점 + 요일 csv파일로 저장

# %%
# url 수집
days_urls, days_titles = [], []

url = 'https://comic.naver.com/webtoon/weekday'

resp = requests.get(url)

soup = BeautifulSoup(resp.content, 'lxml')

a_tags = soup.select('ul.category_tab a')[1:-1]
# Out:
# (['https://comic.naver.com/webtoon/weekdayList?week=mon',
#   'https://comic.naver.com/webtoon/weekdayList?week=tue',
#   'https://comic.naver.com/webtoon/weekdayList?week=wed',
#   'https://comic.naver.com/webtoon/weekdayList?week=thu',
#   'https://comic.naver.com/webtoon/weekdayList?week=fri',
#   'https://comic.naver.com/webtoon/weekdayList?week=sat',
#   'https://comic.naver.com/webtoon/weekdayList?week=sun'],
#  ['월요웹툰', '화요웹툰', '수요웹툰', '목요웹툰', '금요웹툰', '토요웹툰', '일요웹툰'])

# %%
titles, authors, ratings, weekdays = [], [], [], []

# %%
import pandas as pd

df_toons = pd.DataFrame({'title' : titles, 'author' : authors, 
                         'rating' : ratings, 'weekday' : weekdays})
df_toons.to_csv('네이버웹툰정보.csv', index=False, encoding='utf-8-sig')

# %%
toons_info = pd.read_csv('네이버웹툰정보.csv')
toons_info
# Out:
#           title             author  rating weekday
# 0           참교육          채용택 / 한가람    9.87    월요웹툰
# 1       뷰티풀 군바리           설이 / 윤성원    9.81    월요웹툰
# 2       퀘스트지상주의           박태준 만화회사    9.80    월요웹툰
# 3     장씨세가 호위무사          김인호 / 조형근    9.93    월요웹툰
# 4        윈드브레이커                조용석    9.83    월요웹툰
# ..          ...                ...     ...     ...
# 573     조선여우스캔들     문종호 / 정후 / 차소희    9.93    일요웹툰
# 574   밀실 마피아 게임  WONS / 백지운 / P...    9.41    일요웹툰
# 575  천년간 노려왔습니다                 수빈    9.90    일요웹툰
# 576      그림자 잡기                 최날    9.64    일요웹툰
# 577        어떤소란                 케첩    9.83    일요웹툰
#
# [578 rows x 4 columns]

# %%
toons_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    578 non-null    object
#  1   author   578 non-null    object
#  2   rating   578 non-null    float64
#  3   weekday  578 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 18.2+ KB

# %%
# 평점은 float형으로 저장되도록 해서, 
# 평점의 평균, 중앙값을 출력해보세요.
toons_info['rating'].mean()
# Out:
# 9.833079584775087

# %%
# 요일별 평점 평균, 중앙값 비교
# 요일이 같은 데이터끼리 묶어서 -> 각각 평균, 중앙값 계산
# 묶어서 (== groupby) A.groupby([b])
mean_by_weekday = toons_info.groupby(['weekday']).mean()
mean_by_weekday.sort_values('rating', ascending=False, inplace=True)
mean_by_weekday
# Out:
#            rating
# weekday
# 일요웹툰     9.864819
# 토요웹툰     9.855696
# 월요웹툰     9.846071
# 수요웹툰     9.840000
# 금요웹툰     9.835455
# 화요웹툰     9.828250
# 목요웹툰     9.762048

# %% [markdown]
# ### 3. 장르별 웹툰 정보 가져오기

# %%
import requests
from bs4 import BeautifulSoup

# %%
genre_urls, genre_texts = [], []

# %%
# 장르 url, text 수집
url = 'https://comic.naver.com/webtoon/genre'

resp = requests.get(url)

soup = BeautifulSoup(resp.content, 'lxml')
# Out:
# (['https://comic.naver.com/webtoon/genre?genre=daily',
#   'https://comic.naver.com/webtoon/genre?genre=comic',
#   'https://comic.naver.com/webtoon/genre?genre=fantasy',
#   'https://comic.naver.com/webtoon/genre?genre=action',
#   'https://comic.naver.com/webtoon/genre?genre=drama',
#   'https://comic.naver.com/webtoon/genre?genre=pure',
#   'https://comic.naver.com/webtoon/genre?genre=sensibility',
#   'https://comic.naver.com/webtoon/genre?genre=thrill',
#   'https://comic.naver.com/webtoon/genre?genre=historical',
#   'https://comic.naver.com/webtoon/genre?genre=sports'],
#  ['일상', '개그', '판타지', '액션', '드라마', '순정', '감성', '스릴러', '무협/사극', '스포츠'])

# %%
titles, authors, ratings, genres = [], [], [], []

# %%
# Out:
# (2115, 2115, 2115, 2115)

# %%
import pandas as pd

df_toons_by_genre = pd.DataFrame({'제목' : titles,
                                  '작가' : authors,
                                  '평점' : ratings,
                                  '장르' : genres})

df_toons_by_genre
# Out:
#              제목   작가    평점   장르
# 0      대학원 탈출일지   요다  9.98   일상
# 1         먹는 인생   홍끼  9.96   일상
# 2          독립일기   자까  9.97   일상
# 3        그냥 선생님   연일  9.97   일상
# 4     안녕, 나의 수집   하린  9.96   일상
# ...         ...  ...   ...  ...
# 2110         군주  박산하  8.50  스포츠
# 2111     불릿 6미리  김도근  9.89  스포츠
# 2112   미드나잇 체이서  석재윤  9.60  스포츠
# 2113         리턴  송래현  9.85  스포츠
# 2114       번데기스  김경호  7.97  스포츠
#
# [2115 rows x 4 columns]

# %%
df_toons_by_genre['평점'] = df_toons_by_genre['평점'].astype('float')
df_toons_by_genre['평점'].dtypes
# Out:
# dtype('float64')

# %%
# 장르별 평점 평균, 중앙값 비교
display(df_toons_by_genre.groupby(['장르']).mean())
display(df_toons_by_genre.groupby(['장르']).median())
# Out:
#              평점
# 장르
# 감성     9.905455
# 개그     9.655725
# 드라마    9.746479
# 무협/사극  9.883864
# 순정     9.818481
# 스릴러    9.686298
# 스포츠    9.556087
# 액션     9.554350
# 일상     9.665625
# 판타지    9.736077
#          평점
# 장르
# 감성     9.93
# 개그     9.90
# 드라마    9.91
# 무협/사극  9.91
# 순정     9.93
# 스릴러    9.87
# 스포츠    9.81
# 액션     9.83
# 일상     9.89
# 판타지    9.92

# %%
# 장르별 평점 평균 내림차순 정렬
mean_by_genre = df_toons_by_genre.groupby(['장르']).mean()
mean_by_genre.sort_values('평점', ascending=False)
# Out:
#              평점
# 장르
# 감성     9.905455
# 무협/사극  9.883864
# 순정     9.818481
# 드라마    9.746479
# 판타지    9.736077
# 스릴러    9.686298
# 일상     9.665625
# 개그     9.655725
# 스포츠    9.556087
# 액션     9.554350

# %% [markdown]
# ### 4. 웹툰 섬네일 가져오기

# %% [markdown]
# #### 이미지 크롤링의 이해
# html 안에 이미지는 없다. 이미지의 src만 있을 뿐.
#
# - 1단계 : 섬네일 이미지 태그에서 img src 가져오기
# - 2단계 : 이미지 src에 requests get하여 img 가져오기

# %% [markdown]
# #### 4-1) 하나의 웹툰을 정하여 해당 웹툰의 섬네일 이미지 저장하기

# %%
import requests
from bs4 import BeautifulSoup

# %%
# 예시, 김부장 섬네일
# Out:
# 'https://shared-comic.pstatic.net/thumb/webtoon/783053/thumbnail/thumbnail_IMAG10_7e1a48d2-11e0-4455-a668-fff349d8b3f3.jpg'

# %%
# resp_img.content가 섬네일 이미지

# %% [markdown]
# #### 4-2) 액션 페이지의 웹툰 섬네일 이미지 가져와보기
# - 액션 페이지 url에 requests get하여 resp.content 가져오기
# - title_tags, thumb_tags 가져오기
#
# - 두 태그 같이 for문 돌면서 title, thumb_src 가져오기
# - thumb_src에 requests get 하여 섬네일 이미지(resp_img.content) 가져오기
# - with open as f 로 title.jpg라는 이름으로 섬네일 이미지 파일 저장하기

# %%
import requests
from bs4 import BeautifulSoup

# %%
# 1단계 : 섬네일 이미지 태그에서 img src 가져오기
# Out:
# 177 177
# 김부장
# https://shared-comic.pstatic.net/thumb/webtoon/783053/thumbnail/thumbnail_IMAG10_7e1a48d2-11e0-4455-a668-fff349d8b3f3.jpg
# 참교육
# https://shared-comic.pstatic.net/thumb/webtoon/758037/thumbnail/thumbnail_IMAG10_a2297504-4912-4c7e-a5a8-524d6fc77103.jpg
# 약한영웅
# https://shared-comic.pstatic.net/thumb/webtoon/710751/thumbnail/thumbnail_IMAG10_f0f51e5a-a2f2-4404-8ace-866ab7fd1af3.jpg
# 헬퍼 2 : 킬베로스
# https://shared-comic.pstatic.net/thumb/webtoon/670143/thumbnail/thumbnail_IMAG10_d2f956f7-2541-4b97-b933-e4aaa2564d14.jpg
# 싸움독학
# https://shared-comic.pstatic.net/thumb/webtoon/736277/thumbnail/thumbnail_IMAG10_3ff8475e-6085-4188-a359-920a8801b419.jpg
# 입학용병
# https://shared-comic.pstatic.net/thumb/webtoon/758150/thumbnail/thumbnail_IMAG10_c03df7c9-dbf3-4314-8699-04ce77fb4444.jpg
# 사신소년
# https://shared-comic.pstatic.net/thumb/webtoon/730656/thumbnail/thumbnail_IMAG10_dccdbdce-3edd-4437-983d-6b20f4965688.jpg
# 일렉시드
# ...

# %% [markdown]
# 액션 페이지 url에 requests get하여 resp.content 가져오기
#
# thumb_tags 가져오기
#
# for문 돌면서 title, thumb_src 가져오기
#
# thumb_src에 requests get 하여 섬네일 이미지(resp_img.content) 가져오기
#
# with open as f 로 title.jpg라는 이름으로 섬네일 이미지 파일 저장하기

# %%
import requests
from bs4 import BeautifulSoup

# %%
# !mkdir toon_thumb

# %%
url = 'https://comic.naver.com/webtoon/genre?genre=action'

resp = requests.get(url)

soup = BeautifulSoup(resp.content, 'lxml')

# %% [markdown]
# #### 4-3) 요일별 페이지를 돌면서 모든 웹툰 섬네일 이미지 저장하기

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://comic.naver.com/webtoon/weekday'

resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
urls = []

# %%
soup = BeautifulSoup(resp.content, 'lxml')
# Out:
# ['https://comic.naver.com/webtoon/weekdayList?week=mon',
#  'https://comic.naver.com/webtoon/weekdayList?week=tue',
#  'https://comic.naver.com/webtoon/weekdayList?week=wed',
#  'https://comic.naver.com/webtoon/weekdayList?week=thu',
#  'https://comic.naver.com/webtoon/weekdayList?week=fri',
#  'https://comic.naver.com/webtoon/weekdayList?week=sat',
#  'https://comic.naver.com/webtoon/weekdayList?week=sun']

# %%
# !mkdir webtoon_thumb

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-e845d873475c> in <module>
#       9         title = img_tag['title']
#      10
# ---> 11         resp_img = requests.get(src)
#      12
#      13         with open(f'webtoon_thumb/{title}.jpg', 'wb') as f:
#
# /usr/local/lib/python3.8/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.8/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %% [markdown]
# ### 5. kospi200 일별시세 가져오기

# %% [markdown]
# #### iframe 페이지 크롤링의 이해
# - iframe구조인지 파악(눈치채기) :
#     - 페이지가 바뀌는데, url이 안바뀐다.
#     - 페이지 구조상 안바뀌는게 맞는 것 같을 때
# - html에서 iframe 태그 찾기 -> src 가져오기
# - requests.get(iframe_src)

# %%
# 날짜 :    date
# 체결가:  price
# 전일비:  diff
# 등락률:  rate
# 거래량:  volume
# 거래대금:   amount

# %% [markdown]
# #### 5-1) 1페이지 날짜, 체결가만 가져와서 출력하기

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://finance.naver.com/sise/sise_index_day.naver?code=KPI200'
resp = requests.get(url)
resp

soup = BeautifulSoup(resp.content, 'lxml')
# Out:
# date: 2023.01.18
# price: 311.94
# date: 2023.01.17
# price: 313.75
# date: 2023.01.16
# price: 316.04
# date: 2023.01.13
# price: 313.77
# date: 2023.01.12
# price: 310.70
# date: 2023.01.11
# price: 310.38

# %% [markdown]
# #### 5-2) 1페이지 전체 데이터 가져와서 출력하기

# %%
# Out:
# 2023.01.18 312.32 1.43 -0.46% 17,830 863,755
# 2023.01.17 313.75 2.29 -0.72% 101,245 4,829,876
# 2023.01.16 316.04 2.27 +0.72% 119,827 5,136,041
# 2023.01.13 313.77 3.07 +0.99% 128,647 5,505,750
# 2023.01.12 310.70 0.32 +0.10% 130,719 6,002,834
# 2023.01.11 310.38 0.81 +0.26% 102,603 5,055,057

# %% [markdown]
# #### 5-3) 1페이지 전체 데이터 가져와서 전일비 양수, 음수 처리한다음, 모든 데이터 데이터프레임에 저장하기

# %%
dates, prices, diffs, rates, volumns, amounts = [], [], [], [], [], []

# %%
url = 'https://finance.naver.com/sise/sise_index_day.naver?code=KPI200'
resp = requests.get(url)

soup = BeautifulSoup(resp.content, 'lxml')

# %%
import pandas as pd

df_ksp200 = pd.DataFrame({'날짜' : dates, '체결가' : prices, '전일비' : diffs,
              '등락률' : rates, '거래량' : volumns, '거래대금' : amounts})
df_ksp200
# Out:
#            날짜     체결가    전일비     등락률      거래량       거래대금
# 0  2023.01.18  311.78  -1.97  -0.63%   22,247  1,066,528
# 1  2023.01.17  313.75  -2.29  -0.72%  101,245  4,829,876
# 2  2023.01.16  316.04   2.27  +0.72%  119,827  5,136,041
# 3  2023.01.13  313.77   3.07  +0.99%  128,647  5,505,750
# 4  2023.01.12  310.70   0.32  +0.10%  130,719  6,002,834
# 5  2023.01.11  310.38   0.81  +0.26%  102,603  5,055,057

# %% [markdown]
# #### 5-4) 전체 페이지 전체 데이터 가져와서 csv파일로 저장하기
# - 코드 시행 시점 무관하게 맨 끝페이지까지 크롤링하도록 자동화할 것.

# %%
url = 'https://finance.naver.com/sise/sise_index_day.naver?code=KPI200'
resp = requests.get(url)

soup = BeautifulSoup(resp.content, 'lxml')
# Out:
# 703

# %%
dates, prices, diffs, rates, volumns, amounts = [], [], [], [], [], []

# %%
# 마지막 페이지 정보 누락되어있을 경우 확인
last_url = 'https://finance.naver.com/sise/sise_index_day.naver?code=KPI200&page=703'
resp = requests.get(last_url)

soup = BeautifulSoup(resp.content, 'lxml')
# Out:
# ['2006.01.04', '2006.01.03']

# %%
from tqdm.notebook import tqdm

# %%
dates, prices, diffs, rates, volumns, amounts = [], [], [], [], [], []
# Out:
# 코스피200 일별시세:   0%|          | 0/703 [00:00<?, ?it/s]

# %%
len(dates)
# Out:
# 4214

# %%
# Out:
# 4214

# %%
import pandas as pd

df_ksp200 = pd.DataFrame({'날짜' : dates, '체결가' : prices, '전일비' : diffs,
              '등락률' : rates, '거래량' : volumns, '거래대금' : amounts})
df_ksp200
# Out:
#               날짜     체결가    전일비     등락률      거래량       거래대금
# 0     2023.01.18  310.78  -2.97  -0.95%   37,513  1,742,388
# 1     2023.01.17  313.75  -2.29  -0.72%  101,245  4,829,876
# 2     2023.01.16  316.04   2.27  +0.72%  119,827  5,136,041
# 3     2023.01.13  313.77   3.07  +0.99%  128,647  5,505,750
# 4     2023.01.12  310.70   0.32  +0.10%  130,719  6,002,834
# ...          ...     ...    ...     ...      ...        ...
# 4209  2006.01.09  180.30  -0.57  -0.32%  191,222  4,641,279
# 4210  2006.01.06  180.87   2.05  +1.15%  206,313  4,609,858
# 4211  2006.01.05  178.82  -1.09  -0.61%  206,332  5,522,148
# 4212  2006.01.04  179.91   1.10  +0.62%  188,841  5,360,812
# 4213  2006.01.03  178.81   0.52  +0.29%  158,041  4,161,549
#
# [4214 rows x 6 columns]

# %%
# (추가 과제) 네이버 금융에서 Kospi200 일별시세 정보를 모두 csv로 저장해보세요.
df_ksp200.to_csv('코스피200_일별시세.csv', encoding='utf-8-sig', index=False)

ksp200 = pd.read_csv('코스피200_일별시세.csv')
ksp200
# Out:
#               날짜     체결가   전일비     등락률      거래량       거래대금
# 0     2023.01.18  310.78 -2.97  -0.95%   37,513  1,742,388
# 1     2023.01.17  313.75 -2.29  -0.72%  101,245  4,829,876
# 2     2023.01.16  316.04  2.27  +0.72%  119,827  5,136,041
# 3     2023.01.13  313.77  3.07  +0.99%  128,647  5,505,750
# 4     2023.01.12  310.70  0.32  +0.10%  130,719  6,002,834
# ...          ...     ...   ...     ...      ...        ...
# 4209  2006.01.09  180.30 -0.57  -0.32%  191,222  4,641,279
# 4210  2006.01.06  180.87  2.05  +1.15%  206,313  4,609,858
# 4211  2006.01.05  178.82 -1.09  -0.61%  206,332  5,522,148
# 4212  2006.01.04  179.91  1.10  +0.62%  188,841  5,360,812
# 4213  2006.01.03  178.81  0.52  +0.29%  158,041  4,161,549
#
# [4214 rows x 6 columns]

# %%
ksp200.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4214 entries, 0 to 4213
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      4214 non-null   object
#  1   체결가     4214 non-null   float64
#  2   전일비     4214 non-null   float64
#  3   등락률     4214 non-null   object
#  4   거래량     4214 non-null   object
#  5   거래대금    4214 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 197.7+ KB

# %%
# 날짜정보는 datetime으로, 나머지는 numeric으로 변경 후, 통계치 및 시각화를 수행해보세요.
ksp200['등락률'] = ksp200['등락률'].str.replace('%', '')
ksp200['거래량'] = ksp200['거래량'].str.replace(',', '')
ksp200['거래대금'] = ksp200['거래대금'].str.replace(',', '')

# # ksp200['등락률'].replace('%', '')  vs  ksp200['등락률'].str.replace('%', '')
# ksp200['등락률'].replace('%', '') # value 중에 % 인 value를 ''로 변경
# ksp200['등락률'].str.replace('%', '') # value에 %가 포함되어있는 value에 %를 ''로 변경
ksp200['날짜'] = pd.to_datetime(ksp200['날짜'])
ksp200['등락률'] = pd.to_numeric(ksp200['등락률'])
ksp200['거래량'] = pd.to_numeric(ksp200['거래량'])
ksp200['거래대금'] = pd.to_numeric(ksp200['거래대금'])
ksp200.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4214 entries, 0 to 4213
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      4214 non-null   datetime64[ns]
#  1   체결가     4214 non-null   float64
#  2   전일비     4214 non-null   float64
#  3   등락률     4214 non-null   float64
#  4   거래량     4214 non-null   int64
#  5   거래대금    4214 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(2)
# memory usage: 197.7 KB

# %%
ksp200.sort_values('날짜', ascending=True, ignore_index=True, inplace=True)
ksp200
# Out:
#              날짜     체결가   전일비   등락률     거래량     거래대금
# 0    2006-01-03  178.81  0.52  0.29  158041  4161549
# 1    2006-01-04  179.91  1.10  0.62  188841  5360812
# 2    2006-01-05  178.82 -1.09 -0.61  206332  5522148
# 3    2006-01-06  180.87  2.05  1.15  206313  4609858
# 4    2006-01-09  180.30 -0.57 -0.32  191222  4641279
# ...         ...     ...   ...   ...     ...      ...
# 4209 2023-01-12  310.70  0.32  0.10  130719  6002834
# 4210 2023-01-13  313.77  3.07  0.99  128647  5505750
# 4211 2023-01-16  316.04  2.27  0.72  119827  5136041
# 4212 2023-01-17  313.75 -2.29 -0.72  101245  4829876
# 4213 2023-01-18  310.78 -2.97 -0.95   37513  1742388
#
# [4214 rows x 6 columns]

# %%
ksp200.describe() # 기초 통계치 계산
# Out:
#                체결가          전일비          등락률            거래량          거래대금
# count  4214.000000  4214.000000  4214.000000    4214.000000  4.214000e+03
# mean    261.789696     0.031440     0.021512  111786.773849  4.705644e+06
# std      59.783468     3.105404     1.284720   57742.902151  2.577656e+06
# min     123.270000   -16.650000   -10.330000   36693.000000  1.383859e+06
# 25%     230.385000    -1.490000    -0.580000   73153.500000  3.086526e+06
# 50%     256.205000     0.150000     0.060000   94626.000000  3.967430e+06
# 75%     286.582500     1.680000     0.677500  131035.250000  5.480928e+06
# max     440.400000    19.410000    12.230000  622950.000000  3.737996e+07

# %%
from matplotlib import pyplot as plt

plt.plot(ksp200['날짜'], ksp200['체결가'])

# %%
plt.bar(ksp200['날짜'], ksp200['거래량'])
# Out:
# <BarContainer object of 4214 artists>
